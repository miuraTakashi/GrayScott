# %% [markdown]
# # Gray-Scott f-k Parameter Map Visualization
#
# Interactive visualization of Gray-Scott reaction-diffusion patterns.
# Click on any point in the f-k map to view the corresponding GIF animation.

# %% [markdown]
# ## Code

# %%
# Enable interactive backend for pick events
try:
    # %matplotlib widget
    print('Using %matplotlib widget')
except Exception:
    try:
        # %matplotlib notebook
        print('Using %matplotlib notebook')
    except Exception:
        import matplotlib
        print('Interactive backend not available. Current backend:', matplotlib.get_backend())
        print('Install ipympl: pip install ipympl, then restart the kernel.')
# Out:
# Using %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image, display, clear_output
import ipywidgets as widgets
import os

# Import our analysis library
import fk_analysis

# %%
# Load data (uses cache if available, otherwise processes all GIF files)
# First run will take several minutes to process all GIFs
# Subsequent runs will load from cache instantly
# Use separate cache file for gif_band to avoid conflicts with gif folder cache
data = fk_analysis.load_or_process_data(gif_dir='../gif_band', cache_file='fk_data_cache_band.npz', use_cache=True, verbose=True)

f_values = data['f_values']
k_values = data['k_values']
variations = data['variations']
avail_paths = data['paths']
# Out:
# Scanning GIF directory: /Users/miura/_git/GrayScott/gif_band
# Found 15600 GIF files
# Calculating spatial variations from GIF files...
#   Processing 0/15600...
#   Processing 100/15600...
#   Processing 200/15600...
#   Processing 300/15600...
#   Processing 400/15600...
#   Processing 500/15600...
#   Processing 600/15600...
#   Processing 700/15600...
#   Processing 800/15600...
#   Processing 900/15600...
#   Processing 1000/15600...
#   Processing 1100/15600...
#   Processing 1200/15600...
#   Processing 1300/15600...
#   Processing 1400/15600...
#   Processing 1500/15600...
#   Processing 1600/15600...
#   Processing 1700/15600...
#   Processing 1800/15600...
#   Processing 1900/15600...
#   Processing 2000/15600...
#   Processing 2100/15600...
#   Processing 2200/15600...
#   Processing 2300/15600...
#   Processing 2400/15600...
#   Processing 2500/15600...
#   Processing 2600/15600...
#   Processing 2700/15600...
#   Processing 2800/15600...
#   Processing 2900/15600...
#   Processing 3000/15600...
#   Processing 3100/15600...
#   Processing 3200/15600...
#   Processing 3300/15600...
#   Processing 3400/15600...
#   Processing 3500/15600...
#   Processing 3600/15600...
#   Processing 3700/15600...
#   Processing 3800/15600...
#   Processing 3900/15600...
#   Processing 4000/15600...
#   Processing 4100/15600...
#   Processing 4200/15600...
#   Processing 4300/15600...
#   Processing 4400/15600...
#   Processing 4500/15600...
#   Processing 4600/15600...
#   Processing 4700/15600...
#   Processing 4800/15600...
#   Processing 4900/15600...
#   Processing 5000/15600...
#   Processing 5100/15600...
#   Processing 5200/15600...
#   Processing 5300/15600...
#   Processing 5400/15600...
#   Processing 5500/15600...
#   Processing 5600/15600...
#   Processing 5700/15600...
#   Processing 5800/15600...
#   Processing 5900/15600...
#   Processing 6000/15600...
#   Processing 6100/15600...
#   Processing 6200/15600...
#   Processing 6300/15600...
#   Processing 6400/15600...
#   Processing 6500/15600...
#   Processing 6600/15600...
#   Processing 6700/15600...
#   Processing 6800/15600...
#   Processing 6900/15600...
#   Processing 7000/15600...
#   Processing 7100/15600...
#   Processing 7200/15600...
#   Processing 7300/15600...
#   Processing 7400/15600...
#   Processing 7500/15600...
#   Processing 7600/15600...
#   Processing 7700/15600...
#   Processing 7800/15600...
#   Processing 7900/15600...
#   Processing 8000/15600...
#   Processing 8100/15600...
#   Processing 8200/15600...
#   Processing 8300/15600...
#   Processing 8400/15600...
#   Processing 8500/15600...
#   Processing 8600/15600...
#   Processing 8700/15600...
#   Processing 8800/15600...
#   Processing 8900/15600...
#   Processing 9000/15600...
#   Processing 9100/15600...
#   Processing 9200/15600...
#   Processing 9300/15600...
#   Processing 9400/15600...
#   Processing 9500/15600...
#   Processing 9600/15600...
#   Processing 9700/15600...
#   Processing 9800/15600...
#   Processing 9900/15600...
#   Processing 10000/15600...
#   Processing 10100/15600...
#   Processing 10200/15600...
#   Processing 10300/15600...
#   Processing 10400/15600...
#   Processing 10500/15600...
#   Processing 10600/15600...
#   Processing 10700/15600...
#   Processing 10800/15600...
#   Processing 10900/15600...
#   Processing 11000/15600...
#   Processing 11100/15600...
#   Processing 11200/15600...
#   Processing 11300/15600...
#   Processing 11400/15600...
#   Processing 11500/15600...
#   Processing 11600/15600...
#   Processing 11700/15600...
#   Processing 11800/15600...
#   Processing 11900/15600...
#   Processing 12000/15600...
#   Processing 12100/15600...
#   Processing 12200/15600...
#   Processing 12300/15600...
#   Processing 12400/15600...
#   Processing 12500/15600...
#   Processing 12600/15600...
#   Processing 12700/15600...
#   Processing 12800/15600...
#   Processing 12900/15600...
#   Processing 13000/15600...
#   Processing 13100/15600...
#   Processing 13200/15600...
#   Processing 13300/15600...
#   Processing 13400/15600...
#   Processing 13500/15600...
#   Processing 13600/15600...
#   Processing 13700/15600...
#   Processing 13800/15600...
#   Processing 13900/15600...
#   Processing 14000/15600...
#   Processing 14100/15600...
#   Processing 14200/15600...
#   Processing 14300/15600...
#   Processing 14400/15600...
#   Processing 14500/15600...
#   Processing 14600/15600...
#   Processing 14700/15600...
#   Processing 14800/15600...
#   Processing 14900/15600...
#   Processing 15000/15600...
#   Processing 15100/15600...
#   Processing 15200/15600...
#   Processing 15300/15600...
#   Processing 15400/15600...
#   Processing 15500/15600...
# Processed 15600 GIF files
# f range: [0.0050, 0.0695]
# k range: [0.0400, 0.0698]
# Variation range: [0.00, 1634.01]
# Cache saved to fk_data_cache_band.npz

# %%
# Create GIF preview widgets (128x128 to match actual GIF size)
output_box = widgets.Output(layout=widgets.Layout(
    width='128px', height='128px', overflow='hidden', 
    border='1px solid #ccc', flex='0 0 auto', 
    padding='0px', margin='0px'
))

filename_label = widgets.HTML(
    value='<div style="width:128px; word-wrap:break-word; font-size:12px; text-align:center;">'
          'Click a point to preview</div>'
)

gif_container = widgets.VBox(
    [filename_label, output_box],
    layout=widgets.Layout(gap='4px')
)

# %%
# Build interactive f-k map
plt.ioff()
fig, ax = plt.subplots(figsize=(6, 5))

# Scatter plot with spatial variation as color
sc = ax.scatter(k_values, f_values, c=variations, s=24, alpha=0.7, 
                picker=5, cmap='viridis')
# Color bar removed

ax.set_xlabel('k')
ax.set_ylabel('f')
ax.set_title('f-k Map: Spatial Variation (click to view GIF)')
ax.grid(True, alpha=0.3)

# Add theoretical bifurcation curves
kmin, kmax = k_values.min(), k_values.max()
fmin, fmax = f_values.min(), f_values.max()

def plot_curve_simple(G, klim, flim, ax, color='crimson', linewidth=2, label=None, n=400):
    k = np.linspace(klim[0], klim[1], n)
    f = np.linspace(flim[0], flim[1], n)
    K, F = np.meshgrid(k, f)
    Z = G(F, K)
    if np.iscomplexobj(Z):
        Z = np.where(np.abs(np.imag(Z)) < 1e-10, np.real(Z), np.nan)
    else:
        Z = np.asarray(Z, dtype=float)
    ax.contour(K, F, Z, levels=[0.0], colors=color, linewidths=linewidth, alpha=0.8)
    if label:
        ax.plot([], [], color=color, linewidth=linewidth, label=label)

# Hopf bifurcation curve
def G_Hopf(f, k):
    return 4*k - (f + np.sqrt(f*(f-4*(f+k)**2)))**2 / ((f + k)**2)

plot_curve_simple(G_Hopf, (kmin, kmax), (fmin, fmax), ax, 
                  color='green', linewidth=1.5, label='Hopf')

# Numerical solution boundary
def G_NumSoln(f, k):
    return f - 4*f**2 - 8*f*k - 4*k**2

plot_curve_simple(G_NumSoln, (kmin, kmax), (fmin, fmax), ax, 
                  color='red', linewidth=1.5, label='NumSoln')

ax.legend(loc='upper right', fontsize=9)

# Set aspect ratio
data_range_k = k_values.max() - k_values.min()
data_range_f = f_values.max() - f_values.min()
ax.set_aspect(data_range_k / (1.2 * data_range_f), adjustable='box')

fig.tight_layout(pad=2.0)

last_annotation = None

# Click event handler
def on_pick(event):
    global last_annotation
    if last_annotation is not None:
        last_annotation.remove()
        last_annotation = None

    ind = event.ind
    if len(ind) == 0:
        return
    idx = ind[0]
    f = float(f_values[idx])
    k = float(k_values[idx])
    var = float(variations[idx])

    # Annotate clicked point
    last_annotation = ax.annotate(
        f"f={f:.4f}, k={k:.4f}\\nvar={var:.1f}", (k, f),
        textcoords="offset points", xytext=(10, 10),
        bbox=dict(boxstyle='round,pad=0.3', fc='yellow', alpha=0.6)
    )
    fig.canvas.draw_idle()

    # Find and display GIF
    gif_path = fk_analysis.find_gif_for_fk(f, k, f_values, k_values, avail_paths)
    if not gif_path or not os.path.exists(gif_path):
        print('GIF not found near', (f, k))
        return

    print('Displaying:', gif_path)
    
    # Update filename label
    filename = os.path.basename(gif_path)
    filename_label.value = (
        f'<div style="width:128px; word-wrap:break-word; font-size:12px; text-align:center;">'
        f'{filename}</div>'
    )
    
    # Display GIF at actual size (128x128) with no padding
    with output_box:
        clear_output(wait=True)
        # Read GIF file and encode as base64 to avoid path issues
        import base64
        with open(gif_path, 'rb') as f:
            gif_data = base64.b64encode(f.read()).decode('utf-8')
        # Use HTML img tag with inline style to remove all padding/margin
        from IPython.display import HTML
        display(HTML(f'<img src="data:image/gif;base64,{gif_data}" width="128" height="128" style="display:block; margin:0; padding:0; border:none; line-height:0;" />'))

# Configure canvas and display
fig.canvas.layout = widgets.Layout(
    width='600px', height='500px', 
    border='1px solid #ccc', flex='0 0 auto'
)

container = widgets.HBox(
    [fig.canvas, gif_container],
    layout=widgets.Layout(
        align_items='center', 
        justify_content='flex-start', 
        gap='12px', 
        overflow='visible'
    )
)

clear_output(wait=False)
display(container)

cid = fig.canvas.mpl_connect('pick_event', on_pick)
# Out:
# HBox(children=(Canvas(layout=Layout(border_bottom='1px solid #ccc', border_left='1px solid #ccc', border_right…
